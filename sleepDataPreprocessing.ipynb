# %%
import pandas as pd
from path import Path

# %%
file_path = "Resources/sleepdatacommas.csv"
sleepdata = pd.read_csv(file_path)
sleepdata
# Out:
#                    Start                  End Sleep quality Time in bed  \
# 0    2014-12-29 22:57:49  2014-12-30 07:30:13          100%        8:32
# 1    2014-12-30 21:17:50  2014-12-30 21:33:54            3%        0:16
# 2    2014-12-30 22:42:49  2014-12-31 07:13:31           98%        8:30
# 3    2014-12-31 22:31:01  2015-01-01 06:03:01           65%        7:32
# 4    2015-01-01 22:12:10  2015-01-02 04:56:35           72%        6:44
# ..                   ...                  ...           ...         ...
# 882  2018-02-12 21:54:14  2018-02-13 07:02:15           91%        9:08
# 883  2018-02-13 23:49:19  2018-02-14 07:00:53           81%        7:11
# 884  2018-02-14 21:24:05  2018-02-15 06:20:52           71%        8:56
# 885  2018-02-15 21:36:32  2018-02-16 06:50:31           80%        9:13
# 886  2018-02-16 22:52:29  2018-02-17 07:48:04           91%        8:55
#
#     Wake up             Sleep Notes  Heart rate  Activity (steps)
# ...

# %%
sleepdata['Start'] = pd.to_datetime(sleepdata["Start"])

# %%
sleepdata['End'] = pd.to_datetime(sleepdata["End"])
sleepdata.dtypes
# Out:
# Start               datetime64[ns]
# End                 datetime64[ns]
# Sleep quality               object
# Time in bed                 object
# Wake up                     object
# Sleep Notes                 object
# Heart rate                 float64
# Activity (steps)             int64
# dtype: object

# %%
sleepdata['Sleep quality'] =
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5996/2932319429.py in <module>
# ----> 1 sleepdata['Sleep quality'] = int(sleepdata['Sleep quality'])
#
# ~\.conda\envs\mlenv\lib\site-packages\pandas\core\series.py in wrapper(self)
#     183         if len(self) == 1:
#     184             return converter(self.iloc[0])
# --> 185         raise TypeError(f"cannot convert the series to {converter}")
#     186
#     187     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>

# %%
sleepdata['Sleep Notes']
