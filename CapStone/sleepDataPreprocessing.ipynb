# %%
import pandas as pd
from pymongo import MongoClient
#pip install pymongo[srv]

def read_mongo(db, collection, query={}, host='localhost', port=27017, username=None, password=None, no_id=True):
    # Read from Mongo and Store into DataFrame """
    # Connect to MongoDB
    dbo  = MongoClient("mongodb+srv://MegSpeaks:yVy84qWWLzS9sQx@getsleepy.itaka.mongodb.net/test")

    # Make a query to the specific DB and Collection
    cursor = dbo[db][collection].find(query)

    # Expand the cursor and construct the DataFrame
    df =  pd.DataFrame(list(cursor))

    # Delete the _id
    if no_id:
        del df['_id']

    return df

# %%
df = read_mongo("Sleep_Study", "Sleep_Table")

# %%
df
# Out:
#                 Start               End Sleep quality Time in bed Wake up  \
# 0    12/29/2014 22:57   12/30/2014 7:30          100%        8:32      :)
# 1    12/30/2014 21:17  12/30/2014 21:33            3%        0:16      :|
# 2    12/30/2014 22:42   12/31/2014 7:13           98%        8:30      :|
# 3    12/31/2014 22:31     1/1/2015 6:03           65%        7:32
# 4      1/1/2015 22:12     1/2/2015 4:56           72%        6:44      :)
# ..                ...               ...           ...         ...     ...
# 882   2/12/2018 21:54    2/13/2018 7:02           91%        9:08
# 883   2/13/2018 23:49    2/14/2018 7:00           81%        7:11
# 884   2/14/2018 21:24    2/15/2018 6:20           71%        8:56
# 885   2/15/2018 21:36    2/16/2018 6:50           80%        9:13
# 886   2/16/2018 22:52    2/17/2018 7:48           91%        8:55
#
#     Heart rate Activity (steps) Stressful day Total Drank coffee Total  \
# 0           59                0                   0                  0
# 1           72                0                   1                  0
# 2           57                0                   0                  0
# 3                             0                   0                  0
# 4           68                0                   0                  1
# ..         ...              ...                 ...                ...
# 882                          56                   0                  0
# 883                          64                   0                  0
# 884                        3316                   0                  0
# 885                        6555                   0                  0
# 886                        2291                   0                  0
#
#     Drank tea Total Ate late Total Worked out Total
# 0                 0              0                0
# 1                 0              0                0
# 2                 0              0                0
# 3                 0              0                0
# 4                 1              0                0
# ..              ...            ...              ... ..
# 882               0              0                0
# 883               0              0                0
# 884               0              0                0
# 885               0              0                0
# 886               0              0                0
#
# [887 rows x 13 columns]

# %%
df.dtypes
# Out:
# Start                  object
# End                    object
# Sleep quality          object
# Time in bed            object
# Wake up                object
# Heart rate             object
# Activity (steps)       object
# Stressful day Total    object
# Drank coffee Total     object
# Drank tea Total        object
# Ate late Total         object
# Worked out Total       object
#                        object
# dtype: object

# %%
df['Start'] = pd.to_datetime(df["Start"])

# %%
df['End'] = pd.to_datetime(df["End"])
df.dtypes
# Out:
# Start                  datetime64[ns]
# End                    datetime64[ns]
# Sleep quality                  object
# Time in bed                    object
# Wake up                        object
# Heart rate                     object
# Activity (steps)               object
# Stressful day Total            object
# Drank coffee Total             object
# Drank tea Total                object
# Ate late Total                 object
# Worked out Total               object
#                                object
# dtype: object

# %%
df['Sleep quality'] = df['Sleep quality'].str.replace('%', '')

# %%
df['Sleep quality'] = df['Sleep quality'].astype('int')
df['Activity (steps)'] = df['Activity (steps)'].astype('int')
df['Stressful day Total'] = df['Stressful day Total'].astype('int')
df['Drank coffee Total'] = df['Drank coffee Total'].astype('int')
df['Drank tea Total'] = df['Drank tea Total'].astype('int')
df['Ate late Total'] = df['Ate late Total'].astype('int')
df['Worked out Total'] = df['Worked out Total'].astype('int')
df['Heart rate'] = df['Heart rate'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-a24c0116ea68> in <module>
#       6 df['Ate late Total'] = df['Ate late Total'].astype('int')
#       7 df['Worked out Total'] = df['Worked out Total'].astype('int')
# ----> 8 df['Heart rate'] = df['Heart rate'].astype('int')
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1072         # work around NumPy brokenness, #1987
#    1073         if np.issubdtype(dtype.type, np.integer):
# -> 1074             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#    1075
#    1076         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: ''

# %%
df.dtypes
# Out:
# Start                  datetime64[ns]
# End                    datetime64[ns]
# Sleep quality                   int32
# Time in bed                    object
# Wake up                        object
# Heart rate                     object
# Activity (steps)                int32
# Stressful day Total             int32
# Drank coffee Total              int32
# Drank tea Total                 int32
# Ate late Total                  int32
# Worked out Total                int32
#                                object
# dtype: object
